# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from utils import ada_boost_classifier, decision_tree, preprocessing, random_forest_classifier, visualization

# %%
df_chips = pd.read_csv('./data/raw/chips.csv')
df_geyser = pd.read_csv('./data/raw/geyser.csv')

# %%
df_chips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       118 non-null    float64
#  1   y       118 non-null    float64
#  2   class   118 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.9+ KB

# %%
df_geyser.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       222 non-null    int64
#  1   y       222 non-null    float64
#  2   class   222 non-null    object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 5.3+ KB

# %%
preprocessing.preprocessing_initial_data(df_chips)
preprocessing.preprocessing_initial_data(df_geyser)

# %%
visualization.visualization_initial_data(df_chips, 'Chips')

# %%
visualization.visualization_initial_data(df_geyser, 'Geyser')

# %%
X_Geyser = df_geyser.values[:, :-1]
Y_Geyser = df_geyser.values[:, -1]

X_Chips = df_chips.values[:, :-1]
Y_Chips = df_chips.values[:, -1]

# %%
# X_train_Geyser, X_test_Geyser, y_train_Geyser, y_test_Geyser = train_test_split(
#     X_Geyser, Y_Geyser, test_size=0.2, random_state=1
# )
#
# X_train_Chips, X_test_Chips, y_train_Chips, y_test_Chips = train_test_split(
#     X_Chips, Y_Chips, test_size=0.2, random_state=1
# )

# %%
random_forest_classifier_Geyser = random_forest_classifier.RandomForestClassifier(n_estimators=10)
random_forest_classifier_Geyser.fit(X_Geyser, Y_Geyser)

random_forest_classifier_Chips = random_forest_classifier.RandomForestClassifier(n_estimators=10)
random_forest_classifier_Chips.fit(X_Chips, Y_Chips)

# %%
ada_boost_classifier_Geyser = ada_boost_classifier.AdaBoostClassifier()
ada_boost_classifier_Geyser.fit(X_Geyser, Y_Geyser)

ada_boost_classifier_Chips = ada_boost_classifier.AdaBoostClassifier()
ada_boost_classifier_Chips.fit(X_Chips, Y_Chips)

# %%
fig, ax = plt.subplots(figsize=(15, 15))
grid, ax = visualization.plot_model1(random_forest_classifier_Geyser, X_Geyser, Y_Geyser, ax)

# %%
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Geyser, Y_Geyser, random_forest_classifier_Geyser, ax=ax)

# %%
fig, ax = plt.subplots(figsize=(15, 15))
grid, ax = visualization.plot_model1(random_forest_classifier_Chips, X_Chips, Y_Chips, ax)

# %%
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Chips, Y_Chips, random_forest_classifier_Chips, ax=ax)

# %%
steps_set = [1, 2, 3, 5, 8, 13, 21, 34, 55]

# %%
ada_boost_classifier_Geyser.M = 1
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Geyser, Y_Geyser, ada_boost_classifier_Geyser, ax=ax)

# %%
ada_boost_classifier_Geyser.M = 2
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Geyser, Y_Geyser, ada_boost_classifier_Geyser, ax=ax)

# %%
ada_boost_classifier_Geyser.M = 3
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Geyser, Y_Geyser, ada_boost_classifier_Geyser, ax=ax)

# %%
ada_boost_classifier_Geyser.M = 5
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Geyser, Y_Geyser, ada_boost_classifier_Geyser, ax=ax)

# %%
ada_boost_classifier_Geyser.M = 8
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Geyser, Y_Geyser, ada_boost_classifier_Geyser, ax=ax)

# %%
ada_boost_classifier_Geyser.M = 13
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Geyser, Y_Geyser, ada_boost_classifier_Geyser, ax=ax)

# %%
ada_boost_classifier_Geyser.M = 21
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Geyser, Y_Geyser, ada_boost_classifier_Geyser, ax=ax)

# %%
ada_boost_classifier_Geyser.M = 34
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Geyser, Y_Geyser, ada_boost_classifier_Geyser, ax=ax)

# %%
ada_boost_classifier_Geyser.M = 55
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Geyser, Y_Geyser, ada_boost_classifier_Geyser, ax=ax)

# %%
ada_boost_classifier_Chips.M = 1
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Chips, Y_Chips, ada_boost_classifier_Chips, ax=ax)

# %%
ada_boost_classifier_Chips.M = 2
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Chips, Y_Chips, ada_boost_classifier_Chips, ax=ax)

# %%
ada_boost_classifier_Chips.M = 3
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Chips, Y_Chips, ada_boost_classifier_Chips, ax=ax)

# %%
ada_boost_classifier_Chips.M = 5
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Chips, Y_Chips, ada_boost_classifier_Chips, ax=ax)

# %%
ada_boost_classifier_Chips.M = 8
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Chips, Y_Chips, ada_boost_classifier_Chips, ax=ax)

# %%
ada_boost_classifier_Chips.M = 13
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Chips, Y_Chips, ada_boost_classifier_Chips, ax=ax)

# %%
ada_boost_classifier_Chips.M = 21
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Chips, Y_Chips, ada_boost_classifier_Chips, ax=ax)

# %%
ada_boost_classifier_Chips.M = 34
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Chips, Y_Chips, ada_boost_classifier_Chips, ax=ax)

# %%
ada_boost_classifier_Chips.M = 55
fig, ax = plt.subplots(figsize=(15, 15))
ax = visualization.plot_model2(X_Chips, Y_Chips, ada_boost_classifier_Chips, ax=ax)

# %%
from sklearn.metrics import accuracy_score
accuracy = []
iterations = np.arange(1, 56)
for i in iterations:
   ada_boost_classifier_Geyser.M = i
   predictions = ada_boost_classifier_Geyser.predict(X_Geyser)
   accuracy.append(accuracy_score(Y_Geyser, predictions))

fig, ax = plt.subplots()
ax.plot(iterations, accuracy, linewidth=2.0)

# %%
accuracy = []
iterations = np.arange(1, 56)
for i in iterations:
   ada_boost_classifier_Chips.M = i
   predictions = ada_boost_classifier_Chips.predict(X_Chips)
   accuracy.append(accuracy_score(Y_Chips, predictions))

fig, ax = plt.subplots()
ax.plot(iterations, accuracy, linewidth=2.0)
