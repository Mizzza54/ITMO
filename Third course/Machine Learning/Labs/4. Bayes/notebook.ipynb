# %%
from utils import core
from utils import hyperparameter_optimization
from utils import utils
from utils import visualization

# %%
X, Y = utils.read_all_parts(10, 1)
models = hyperparameter_optimization.init_models(X, Y)

# %%
hyperparameter_optimization.alpha_optimization(models)
# Out:
# ----------
# Alpha:  1e-10
# Accuracy:  0.9761467889908257
# ----------
# Alpha:  1e-09
# Accuracy:  0.9770642201834863
# ----------
# Alpha:  1e-08
# Accuracy:  0.9761467889908257
# ----------
# Alpha:  1e-07
# Accuracy:  0.9752293577981652
# ----------
# Alpha:  1e-06
# Accuracy:  0.9761467889908257
# ----------
# Alpha:  1e-05
# Accuracy:  0.9715596330275229
# ----------
# Alpha:  0.0001
# Accuracy:  0.9669724770642203
# ----------
# Alpha:  0.001
# Accuracy:  0.9577981651376147
# ----------
# Alpha:  0.01
# Accuracy:  0.9495412844036698
# ----------
# Alpha:  0.1
# Accuracy:  0.9201834862385321
# ----------
# Alpha:  1
# Accuracy:  0.8669724770642201
# ----------
# Alpha:  10
# Accuracy:  0.7706422018348624
# ----------
# Alpha:  100
# Accuracy:  0.6522935779816514
# (0.9770642201834863, 1e-09)

# %%
X_flat = [item for sublist in X for item in sublist]
Y_flat = [item for sublist in Y for item in sublist]
model = core.NaiveBayesClassifier(X_flat, Y_flat, [1, 1], 1e-09)

# %%
visualization.plot_receiver_operating_characteristic(X, Y, model)

# %%
hyperparameter_optimization.lambda_optimization(models, 1e-09)
# Out:
# ----------
# Legit lambda 1e290.0
# Legit lambda:
# Count:  1
# Accuracy:  0.7651376146788992
# ----------
# Legit lambda 1e291.0
# Legit lambda:
# Count:  1
# Accuracy:  0.7651376146788992
# ----------
# Legit lambda 1e292.0
# Legit lambda:
# Count:  0
# Accuracy:  0.7651376146788992
# ----------
# Legit lambda 1e293.0
# Legit lambda:
# Count:  0
# Accuracy:  0.7651376146788992
# ----------
# Legit lambda 1e294.0
# Legit lambda:
# Count:  0
# Accuracy:  0.7651376146788992
# ----------
# Legit lambda 1e295.0
# Legit lambda:
# Count:  0
# Accuracy:  0.7651376146788992
# ----------
# Legit lambda 1e296.0
# Legit lambda:
# Count:  0
# Accuracy:  0.7642201834862385
# ----------
# Legit lambda 1e297.0
# Legit lambda:
# Count:  0
# Accuracy:  0.7642201834862385
# ----------
# Legit lambda 1e298.0
# Legit lambda:
# Count:  0
# Accuracy:  0.763302752293578
# ----------
# Legit lambda 1e299.0
# Legit lambda:
# Count:  0
# Accuracy:  0.763302752293578
# (0.7651376146788992,
# ...

# %%
model = core.NaiveBayesClassifier(X_flat, Y_flat, [1e294, 1], 1e-09)

# %%
visualization.plot_legit_lambda_accuracy(X, Y, model, 0, 294)

# %%
visualization.plot_legit_lambda_legit_accuracy(X, Y, model, 0, 294)

# %%
X, Y = utils.read_all_parts(10, 2)
models = hyperparameter_optimization.init_models(X, Y)

# %%
hyperparameter_optimization.alpha_optimization(models)
# Out:
# ----------
# Alpha:  1e-10
# Accuracy:  0.9807339449541285
# ----------
# Alpha:  1e-09
# Accuracy:  0.9807339449541285
# ----------
# Alpha:  1e-08
# Accuracy:  0.9807339449541285
# ----------
# Alpha:  1e-07
# Accuracy:  0.9807339449541285
# ----------
# Alpha:  1e-06
# Accuracy:  0.9798165137614679
# ----------
# Alpha:  1e-05
# Accuracy:  0.9779816513761469
# ----------
# Alpha:  0.0001
# Accuracy:  0.9770642201834863
# ----------
# Alpha:  0.001
# Accuracy:  0.9715596330275229
# ----------
# Alpha:  0.01
# Accuracy:  0.965137614678899
# ----------
# Alpha:  0.1
# Accuracy:  0.9532110091743121
# ----------
# Alpha:  1
# Accuracy:  0.8853211009174311
# ----------
# Alpha:  10
# Accuracy:  0.7165137614678898
# ----------
# Alpha:  100
# Accuracy:  0.5155963302752294
# (0.9807339449541285, 1e-10)

# %%
X_flat = [item for sublist in X for item in sublist]
Y_flat = [item for sublist in Y for item in sublist]
model = core.NaiveBayesClassifier(X_flat, Y_flat, [1, 1], 1e-10)

# %%
visualization.plot_receiver_operating_characteristic(X, Y, model)

# %%
hyperparameter_optimization.lambda_optimization(models, 1e-10)
# Out:
# ----------
# Legit lambda 1e290.0
# Legit lambda:
# Count:  2
# Accuracy:  0.9027522935779816
# ----------
# Legit lambda 1e291.0
# Legit lambda:
# Count:  2
# Accuracy:  0.9018348623853211
# ----------
# Legit lambda 1e292.0
# Legit lambda:
# Count:  2
# Accuracy:  0.9018348623853211
# ----------
# Legit lambda 1e293.0
# Legit lambda:
# Count:  2
# Accuracy:  0.9018348623853211
# ----------
# Legit lambda 1e294.0
# Legit lambda:
# Count:  2
# Accuracy:  0.9018348623853211
# ----------
# Legit lambda 1e295.0
# Legit lambda:
# Count:  2
# Accuracy:  0.9018348623853211
# ----------
# Legit lambda 1e296.0
# Legit lambda:
# Count:  2
# Accuracy:  0.9018348623853211
# ----------
# Legit lambda 1e297.0
# Legit lambda:
# Count:  2
# Accuracy:  0.9009174311926605
# ----------
# Legit lambda 1e298.0
# Legit lambda:
# Count:  2
# Accuracy:  0.9009174311926605
# ----------
# Legit lambda 1e299.0
# Legit lambda:
# Count:  2
# Accuracy:  0.9009174311926605
# (-1, None)

# %%
model = core.NaiveBayesClassifier(X_flat, Y_flat, [1e299, 1], 1e-10)

# %%
visualization.plot_legit_lambda_accuracy(X, Y, model, 0, 299)

# %%
visualization.plot_legit_lambda_legit_accuracy(X, Y, model, 0, 299)

# %%
X, Y = utils.read_all_parts(10, 3)
models = hyperparameter_optimization.init_models(X, Y)

# %%
hyperparameter_optimization.alpha_optimization(models)
# Out:
# ----------
# Alpha:  1e-10
# Accuracy:  0.9761467889908257
# ----------
# Alpha:  1e-09
# Accuracy:  0.9752293577981652
# ----------
# Alpha:  1e-08
# Accuracy:  0.9752293577981652
# ----------
# Alpha:  1e-07
# Accuracy:  0.9770642201834863
# ----------
# Alpha:  1e-06
# Accuracy:  0.9752293577981652
# ----------
# Alpha:  1e-05
# Accuracy:  0.9724770642201834
# ----------
# Alpha:  0.0001
# Accuracy:  0.9706422018348624
# ----------
# Alpha:  0.001
# Accuracy:  0.965137614678899
# ----------
# Alpha:  0.01
# Accuracy:  0.9513761467889909
# ----------
# Alpha:  0.1
# Accuracy:  0.9220183486238531
# ----------
# Alpha:  1
# Accuracy:  0.8137614678899082
# ----------
# Alpha:  10
# Accuracy:  0.5752293577981652
# ----------
# Alpha:  100
# Accuracy:  0.48990825688073397
# (0.9770642201834863, 1e-07)

# %%
X_flat = [item for sublist in X for item in sublist]
Y_flat = [item for sublist in Y for item in sublist]
model = core.NaiveBayesClassifier(X_flat, Y_flat, [1, 1], 1e-07)

# %%
visualization.plot_receiver_operating_characteristic(X, Y, model)

# %%
hyperparameter_optimization.lambda_optimization(models, 1e-07)
# Out:
# ----------
# Legit lambda 1e290.0
# Legit lambda:
# Count:  4
# Accuracy:  0.8715596330275229
# ----------
# Legit lambda 1e291.0
# Legit lambda:
# Count:  4
# Accuracy:  0.8715596330275229
# ----------
# Legit lambda 1e292.0
# Legit lambda:
# Count:  4
# Accuracy:  0.8706422018348624
# ----------
# Legit lambda 1e293.0
# Legit lambda:
# Count:  4
# Accuracy:  0.8706422018348624
# ----------
# Legit lambda 1e294.0
# Legit lambda:
# Count:  4
# Accuracy:  0.8706422018348624
# ----------
# Legit lambda 1e295.0
# Legit lambda:
# Count:  4
# Accuracy:  0.8706422018348624
# ----------
# Legit lambda 1e296.0
# Legit lambda:
# Count:  4
# Accuracy:  0.8697247706422019
# ----------
# Legit lambda 1e297.0
# Legit lambda:
# Count:  4
# Accuracy:  0.8697247706422019
# ----------
# Legit lambda 1e298.0
# Legit lambda:
# Count:  4
# Accuracy:  0.8697247706422019
# ----------
# Legit lambda 1e299.0
# Legit lambda:
# Count:  4
# Accuracy:  0.8697247706422019
# (-1, None)

# %%
model = core.NaiveBayesClassifier(X_flat, Y_flat, [1e299, 1], 1e-07)

# %%
visualization.plot_legit_lambda_accuracy(X, Y, model, 0, 299)

# %%
visualization.plot_legit_lambda_legit_accuracy(X, Y, model, 0, 299)
